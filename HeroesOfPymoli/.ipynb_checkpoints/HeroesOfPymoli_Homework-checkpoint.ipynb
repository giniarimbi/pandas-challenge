# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
file_to_load = "Resources/purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
purchase_data = pd.read_csv(file_to_load)

# %% [markdown]
# ## Player Count

# %% [markdown]
# * Display the total number of players

# %%
purchase_data.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %%
#count player count
unique_name=purchase_data.SN.unique()
total_players=unique_name.size
total_players
# Out:
# 576

# %%
df=pd.DataFrame({"Total Players":[total_players]})
df
# Out:
#    Total Players
# 0            576

# %% [markdown]
# ## Purchasing Analysis (Total)

# %% [markdown]
# * Run basic calculations to obtain number of unique items, average price, etc.
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
unique_gender=purchase_data["Gender"].value_counts()
unique_gender
# Out:
# Male                     652
# Female                   113
# Other / Non-Disclosed     15
# Name: Gender, dtype: int64

# %%
unique_ID=len(purchase_data["Item ID"].unique())
unique_ID
# Out:
# 183

# %%
average_price=purchase_data["Price"].mean()
number_of_purchase=purchase_data["Price"].count()
total_revenue=purchase_data["Price"].sum()

# %%
purchase_data.shape
# Out:
# (780, 7)

# %%
#purchase summary
purchase_df=pd.DataFrame({"Number of Unique Items":[unique_ID],
                          "Average Price":[average_price],
                          "Number of Purchase" : [number_of_purchase],
                         "Total Revenue":[total_revenue]})
purchase_df=purchase_df.style.format({"Average Price":"${:.2f}",
                                     "Total Revenue":"${:.2f}"})
purchase_df
# Out:
# <style  type="text/css" >
# </style><table id="T_05dce8d4_5b3a_11ea_9ed0_3cf01110ef27" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Number of Unique Items</th>        <th class="col_heading level0 col1" >Average Price</th>        <th class="col_heading level0 col2" >Number of Purchase</th>        <th class="col_heading level0 col3" >Total Revenue</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_05dce8d4_5b3a_11ea_9ed0_3cf01110ef27level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_05dce8d4_5b3a_11ea_9ed0_3cf01110ef27row0_col0" class="data row0 col0" >183</td>
#                         <td id="T_05dce8d4_5b3a_11ea_9ed0_3cf01110ef27row0_col1" class="data row0 col1" >$3.05</td>
#                         <td id="T_05dce8d4_5b3a_11ea_9ed0_3cf01110ef27row0_col2" class="data row0 col2" >780</td>
# ...

# %% [markdown]
# ## Gender Demographics

# %% [markdown]
# * Percentage and Count of Male Players
#
#
# * Percentage and Count of Female Players
#
#
# * Percentage and Count of Other / Non-Disclosed

# %%
#count total players
total_players_row=len(purchase_data)
total_players_row
# Out:
# 780

# %%
#show unique value and count of unique value
unique_gender=purchase_data["Gender"].unique()
unique_gender
# Out:
# array(['Male', 'Other / Non-Disclosed', 'Female'], dtype=object)

# %%
#create list for male, female, and Other/Non-Disclosed
player_count_list=purchase_data["Gender"].value_counts().tolist()
player_count_list
# Out:
# [652, 113, 15]

# %%
male_count=player_count_list[0]
female_count=player_count_list[1]
other_count=player_count_list[2]

# %%
#calculate percentage male
percent_male_count=male_count/total_players_row*100

#calculate percentage female
percent_female_count=female_count/total_players_row*100

#calculate percentage other
percent_other_count=other_count/total_players_row*100
# Out:
# 83.58974358974359

# %%
#gender demographic summary
gender_demographic_df=pd.DataFrame({"Gender":["Male", "Female", "Other"],
                          "Total Count": player_count_list,
                          "Percentage of Players" : [percent_male_count, percent_female_count, percent_other_count]
                        })
gender_demographic_df=gender_demographic_df.style.format({"Percentage of Players":"{:.2f}%"})
gender_demographic_df
# Out:
# <style  type="text/css" >
# </style><table id="T_7a205936_5b3c_11ea_b23a_3cf01110ef27" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Gender</th>        <th class="col_heading level0 col1" >Total Count</th>        <th class="col_heading level0 col2" >Percentage of Players</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7a205936_5b3c_11ea_b23a_3cf01110ef27level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_7a205936_5b3c_11ea_b23a_3cf01110ef27row0_col0" class="data row0 col0" >Male</td>
#                         <td id="T_7a205936_5b3c_11ea_b23a_3cf01110ef27row0_col1" class="data row0 col1" >652</td>
#                         <td id="T_7a205936_5b3c_11ea_b23a_3cf01110ef27row0_col2" class="data row0 col2" >83.59%</td>
#             </tr>
#             <tr>
# ...

# %% [markdown]
# ## Purchasing Analysis (Gender)

# %%
#purchase count(?)

#avg purchase price per gender

#avg_purchase_male=total purchase male / n count male
#total_purchase=purchase_data["Price"].sum()
#total_purchase


#total purchase price per gender
grouped_gender_df=purchase_data.groupby(['Gender'])
grouped_gender_df.head()

#avg total purchase per person
# Out:
#      Purchase ID             SN  Age                 Gender  Item ID  \
# 0              0        Lisim78   20                   Male      108
# 1              1    Lisovynya38   40                   Male      143
# 2              2     Ithergue48   24                   Male       92
# 3              3  Chamassasya86   24                   Male      100
# 4              4      Iskosia90   23                   Male      131
# 9              9    Chanosian48   35  Other / Non-Disclosed      136
# 15            15      Lisassa64   21                 Female       98
# 18            18      Reunasu60   22                 Female       82
# 22            22   Siarithria38   38  Other / Non-Disclosed       24
# 38            38       Reulae52   10                 Female      116
# 41            41      Assosia88   20                 Female        7
# 55            55      Phaelap26   25                 Female       84
# 82            82     Haerithp41   16  Other / Non-Disclosed      160
# ...

# %% [markdown]
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
#
#
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
#4.1)purchase count per gender
grouped_gender_df["Item ID"].count()
# Out:
# Gender
# Female                   113
# Male                     652
# Other / Non-Disclosed     15
# Name: Item ID, dtype: int64

# %%
#4.1)purchase count per gender in list
purchase_count_pergender=grouped_gender_df["Item ID"].count().tolist()
purchase_count_pergender

#4.2)total purchase price per gender in list & convert to USD
grouped_gender_df["Price"].sum().tolist()

#4.3)average purchase price per gender
grouped_gender_df["Price"].mean()

#4.4)average purchase price per gender in list & convert to USD
average_purchase_pergender=grouped_gender_df["Price"].mean().tolist()

# %%
#4.5)create summary for Purchasing Analysis
gender_demographic_df=pd.DataFrame({"Purchase Count":purchase_count_pergender,
                          "Average Purchase Price": average_purchase_pergender,
                          "Total Purchase Value": player_count_list,
                          #"Avg Total Purchase per person" : average_purchase_perperson,
                        })
gender_demographic_df=gender_demographic_df.style.format({"Average Purchase Price":"${:.2f}", 
                                                         "Total Purchase Value":"${:.2f}"})
gender_demographic_df
# Out:
# <style  type="text/css" >
# </style><table id="T_40b44a82_5b3c_11ea_9704_3cf01110ef27" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Average Purchase Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_40b44a82_5b3c_11ea_9704_3cf01110ef27level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_40b44a82_5b3c_11ea_9704_3cf01110ef27row0_col0" class="data row0 col0" >113</td>
#                         <td id="T_40b44a82_5b3c_11ea_9704_3cf01110ef27row0_col1" class="data row0 col1" >$3.20</td>
#                         <td id="T_40b44a82_5b3c_11ea_9704_3cf01110ef27row0_col2" class="data row0 col2" >$652.00</td>
#             </tr>
#             <tr>
# ...

# %% [markdown]
# ## Age Demographics

# %% [markdown]
# * Establish bins for ages
#
#
# * Categorize the existing players using the age bins. Hint: use pd.cut()
#
#
# * Calculate the numbers and percentages by age group
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: round the percentage column to two decimal points
#
#
# * Display Age Demographics Table

# %%
#5.1) establish bin and range
bins=[0,9,14,19,24,29,34,39,100]
age_range=["<10","10-14","15-19", "20-24", "25-29", "30-34", "35-39","40+" ]

# %%
#5.2) put range age into bin
purchase_data["Age Range"] = pd.cut(purchase_data["Age"], bins, labels=age_range)

# %%
#5.3) calculate total and percentage per age range. use groupedby 
grouped_ageRange_df=purchase_data.groupby(['Age Range'])

# %%
#5.3 total count per age group
total_count=grouped_ageRange_df["Age"].count().tolist()
total_count
# Out:
# [23, 28, 136, 365, 101, 73, 41, 13]

# %%
#5.3 percentage per age group
percentage = (grouped_ageRange_df["Purchase ID"].count())*100/number_of_purchase

# %%
purchasing_age_df=pd.DataFrame({
                          "Total Count": total_count,
                          "Percentage of Players": percentage,
                        })
purchasing_age_df=purchasing_age_df.style.format({"Percentage of Players":"{:.2f}%"})
purchasing_age_df
# Out:
# <style  type="text/css" >
# </style><table id="T_d2636c06_5b3b_11ea_bfa1_3cf01110ef27" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total Count</th>        <th class="col_heading level0 col1" >Percentage of Players</th>    </tr>    <tr>        <th class="index_name level0" >Age Range</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d2636c06_5b3b_11ea_bfa1_3cf01110ef27level0_row0" class="row_heading level0 row0" ><10</th>
#                         <td id="T_d2636c06_5b3b_11ea_bfa1_3cf01110ef27row0_col0" class="data row0 col0" >23</td>
#                         <td id="T_d2636c06_5b3b_11ea_bfa1_3cf01110ef27row0_col1" class="data row0 col1" >2.95%</td>
#             </tr>
#             <tr>
#                         <th id="T_d2636c06_5b3b_11ea_bfa1_3cf01110ef27level0_row1" class="row_heading level0 row1" >10-14</th>
# ...

# %% [markdown]
# #### Purchasing Analysis (Age)

# %% [markdown]
# * Bin the purchase_data data frame by age
#
#
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
#5.4) for every age range, calculate purchase count, avg. purchase price, avg. purchase total per person
#calculate purchase count
purchase_count_age=grouped_ageRange_df["Purchase ID"].count().tolist()
#calculate avg purchase price
average_purchase_age=grouped_ageRange_df["Price"].mean().tolist()
#total purchase value
total_purchase_age=grouped_ageRange_df["Price"].sum().tolist()
#average total purchase per person
avg_total_purchase=grouped_ageRange_df["Price"].sum()/total_person

# %% [raw]
# #4.2)total purchase price per gender
# grouped_gender_df["Price"].sum().tolist()

# %%
#5.3)create summary for Purchasing Analysis
purchasing_age_df=pd.DataFrame({"Purchase Count": purchase_count_age,
                          "Average Purchase Price": average_purchase_age,
                          "Total Purchase Value": total_purchase_age,
                          "Avg Total Purchase per person" : avg_total_purchase,
                        })
purchasing_age_df=purchasing_age_df.style.format({"Average Purchase Price":"${:.2f}",
                                                   "Total Purchase Value":"${:.2f}",
                                                  "Avg Total Purchase per person":"${:.2f}"})
purchasing_age_df
# Out:
# <style  type="text/css" >
# </style><table id="T_a4efb328_5b3a_11ea_9fa6_3cf01110ef27" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Average Purchase Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>        <th class="col_heading level0 col3" >Avg Total Purchase per person</th>    </tr>    <tr>        <th class="index_name level0" >Age Range</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a4efb328_5b3a_11ea_9fa6_3cf01110ef27level0_row0" class="row_heading level0 row0" ><10</th>
#                         <td id="T_a4efb328_5b3a_11ea_9fa6_3cf01110ef27row0_col0" class="data row0 col0" >23</td>
# ...

# %% [markdown]
# ## Top Spenders

# %% [markdown]
# * Run basic calculations to obtain the results in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the total purchase value column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
#6.1) Top Spender
#grouped by SN
grouped_SN_df=purchase_data.groupby(['SN'])

# %%
SN_rank_price=grouped_SN_df.sum()

# %%
spender_total=purchase_data.groupby(["SN"]).sum()["Price"].tolist()
spender_average=purchase_data.groupby(["SN"]).mean()["Price"].tolist()
spender_count=purchase_data.groupby(["SN"]).count()["Price"].tolist()

# %%
spender_df=pd.DataFrame({"Purchase Count":spender_count,
                         "Average Purchase Price":spender_average,
                        "Total Purchase Value":spender_total,
                        })
spender_df
# Out:
#      Purchase Count  Average Purchase Price  Total Purchase Value
# 0                 1                2.280000                  2.28
# 1                 1                4.480000                  4.48
# 2                 1                4.910000                  4.91
# 3                 1                4.320000                  4.32
# 4                 1                1.790000                  1.79
# ..              ...                     ...                   ...
# 571               3                2.073333                  6.22
# 572               2                3.010000                  6.02
# 573               1                4.580000                  4.58
# 574               2                3.945000                  7.89
# 575               3                2.676667                  8.03
#
# [576 rows x 3 columns]

# %%
spender_df_sorted=spender_df.sort_values("Total Purchase Value",ascending=False)
spender_df_sorted=spender_df.style.format({"Total Purchase Value":"{:.2f}%","Average Purchase Price":"{:.2f}%"})
spender_df_sorted
# Out:
# <style  type="text/css" >
# </style><table id="T_e0420f06_5b37_11ea_8815_3cf01110ef27" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Average Purchase Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e0420f06_5b37_11ea_8815_3cf01110ef27level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e0420f06_5b37_11ea_8815_3cf01110ef27row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_e0420f06_5b37_11ea_8815_3cf01110ef27row0_col1" class="data row0 col1" >2.28%</td>
#                         <td id="T_e0420f06_5b37_11ea_8815_3cf01110ef27row0_col2" class="data row0 col2" >2.28%</td>
#             </tr>
#             <tr>
# ...

# %% [markdown]
# ## Most Popular Items

# %% [markdown]
# * Retrieve the Item ID, Item Name, and Item Price columns
#
#
# * Group by Item ID and Item Name. Perform calculations to obtain purchase count, item price, and total purchase value
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the purchase count column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
#7.1 Dataframe for Item ID, Item Name, 
spender_total=purchase_data.groupby(["Item ID","Item Name"])
spender_total.head()

#spender_average=purchase_data.groupby(["SN"]).mean()["Price"]
#spender_count=purchase_data.groupby(["SN"]).count()["Price"]
# Out:
#      Purchase ID             SN  Age Gender  Item ID  \
# 0              0        Lisim78   20   Male      108
# 1              1    Lisovynya38   40   Male      143
# 2              2     Ithergue48   24   Male       92
# 3              3  Chamassasya86   24   Male      100
# 4              4      Iskosia90   23   Male      131
# ..           ...            ...  ...    ...      ...
# 766          766   Aelastirin39   23   Male       58
# 774          774     Jiskjask80   11   Male      101
# 777          777     Yathecal72   20   Male       67
# 778          778        Sisur91    7   Male      101
# 779          779      Ennrian78   24   Male       50
#
#                                      Item Name  Price
# 0    Extraction, Quickblade Of Trembling Hands   3.53
# 1                            Frenzied Scimitar   1.56
# 2                                 Final Critic   4.88
# 3                                  Blindscythe   3.27
# ...

# %%
row_price=spender_total["Price"]

# %%
#7.1 show purchase count, item price, and total purchase value
purchase_count=purchase_data.groupby(["Item ID","Item Name"]).count()["Purchase ID"].tolist()
item_price=spender_total["Price"].mean().tolist()
total_purchase=purchase_data.groupby(["Item ID","Item Name"]).sum()["Price"].tolist()

# %%
#7.1 combine dataframe
popular_items_df=pd.DataFrame({"Purchase Count":purchase_count,
                                "Item Price":item_price,
                               "Total Purchase Value":total_purchase,
                        })

# %%
#7.1 sort dataframe based on purchase count
popular_items_df_sorted=popular_items_df.sort_values("Purchase Count",ascending=False)
popular_items_df_sorted=popular_items_df_sorted.style.format({"Total Purchase Value":"${:.2f}"})
popular_items_df_sorted
# Out:
# <style  type="text/css" >
# </style><table id="T_213facfe_5b37_11ea_a021_3cf01110ef27" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Item Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_213facfe_5b37_11ea_a021_3cf01110ef27level0_row0" class="row_heading level0 row0" >177</th>
#                         <td id="T_213facfe_5b37_11ea_a021_3cf01110ef27row0_col0" class="data row0 col0" >12</td>
#                         <td id="T_213facfe_5b37_11ea_a021_3cf01110ef27row0_col1" class="data row0 col1" >4.23</td>
#                         <td id="T_213facfe_5b37_11ea_a021_3cf01110ef27row0_col2" class="data row0 col2" >$50.76</td>
#             </tr>
#             <tr>
# ...

# %% [markdown]
# ## Most Profitable Items

# %% [markdown]
# * Sort the above table by total purchase value in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the data frame

# %%
#8. Most Profitable Items
#sort based on total purchase value
popular_items_df_sorted=popular_items_df.sort_values("Total Purchase Value",ascending=False)

# %%
selected_df=popular_items_df_sorted
selected_df=selected_df.style.format({"Total Purchase Value":"${:.2f}"})
selected_df
# Out:
# <style  type="text/css" >
# </style><table id="T_34214a34_5b36_11ea_8103_3cf01110ef27" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Item Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_34214a34_5b36_11ea_8103_3cf01110ef27level0_row0" class="row_heading level0 row0" >177</th>
#                         <td id="T_34214a34_5b36_11ea_8103_3cf01110ef27row0_col0" class="data row0 col0" >12</td>
#                         <td id="T_34214a34_5b36_11ea_8103_3cf01110ef27row0_col1" class="data row0 col1" >4.23</td>
#                         <td id="T_34214a34_5b36_11ea_8103_3cf01110ef27row0_col2" class="data row0 col2" >$50.76</td>
#             </tr>
#             <tr>
# ...

# %%
#Analysis: 
    
#1.Male players are the majority of the players
#2.The majority of age range players is 20-24
#3.The top 3 most profitable items and most popular items are the same game.
